# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=80e7df8ebdc2ba76ced93d123dd4b9a2

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | tazovskiy
# Processing Record 3 of Set 1 | yerbogachen
# Processing Record 4 of Set 1 | la rioja
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | komsomolskiy
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | yamada
# Processing Record 14 of Set 1 | genhe
# Processing Record 15 of Set 1 | acapulco
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | mucurapo
# Processing Record 18 of Set 1 | voyvozh
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | vao
# Processing Record 22 of Set 1 | mount gambier
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | catuday
# Processing Record 27 of Set 1 | mandera
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | cabedelo
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | arbore
# Processing Record 32 of Set 1 | bilibino
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | grindavik
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | namtsy
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | hasaki
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | high level
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | luanda
# Processing Record 46 of Set 1 | novo aripuana
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | hirara
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | marsh harbour
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | horadiz
# Processing Record 9 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 2 | arshan
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | hambantota
# Processing Record 13 of Set 2 | samarai
# Processing Record 14 of Set 2 | papara
# Processing Record 15 of Set 2 | bonthe
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | andrelandia
# Processing Record 18 of Set 2 | baoshan
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | palana
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | bubaque
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | gat
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | los llanos de aridane
# Processing Record 28 of Set 2 | tukan
# Processing Record 29 of Set 2 | kidal
# Processing Record 30 of Set 2 | smithers
# Processing Record 31 of Set 2 | kahului
# Processing Record 32 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | canton
# Processing Record 35 of Set 2 | halifax
# Processing Record 36 of Set 2 | portland
# Processing Record 37 of Set 2 | puerto leguizamo
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | broken hill
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | sabha
# Processing Record 42 of Set 2 | viedma
# Processing Record 43 of Set 2 | ambanja
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | lorengau
# Processing Record 46 of Set 2 | iracoubo
# Processing Record 47 of Set 2 | fredericksburg
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | weligama
# Processing Record 1 of Set 3 | jablah
# Processing Record 2 of Set 3 | sisophon
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | prince rupert
# Processing Record 5 of Set 3 | torbay
# Processing Record 6 of Set 3 | flinders
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | fort nelson
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | great falls
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | tabou
# Processing Record 13 of Set 3 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | kurchum
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 18 of Set 3 | bengkulu
# Processing Record 19 of Set 3 | soyo
# Processing Record 20 of Set 3 | saint-michel-des-saints
# Processing Record 21 of Set 3 | zachary
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | saint-georges
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | murray bridge
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | ustka
# Processing Record 29 of Set 3 | morehead
# Processing Record 30 of Set 3 | sorland
# Processing Record 31 of Set 3 | shumskiy
# Processing Record 32 of Set 3 | arlit
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | sao gabriel da cachoeira
# Processing Record 35 of Set 3 | sobolevo
# Processing Record 36 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 3 | orlik
# Processing Record 38 of Set 3 | kataysk
# Processing Record 39 of Set 3 | esfahan
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | kletskaya
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | kotri
# Processing Record 44 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 3 | san carlos de bariloche
# Processing Record 46 of Set 3 | polunochnoye
# Processing Record 47 of Set 3 | markala
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | pandamatenga
# Processing Record 1 of Set 4 | hukay
# Processing Record 2 of Set 4 | along
# Processing Record 3 of Set 4 | yeniseysk
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | rogers
# Processing Record 6 of Set 4 | ridgecrest
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | altagracia de orituco
# Processing Record 9 of Set 4 | the pas
# Processing Record 10 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 4 | adrar
# Processing Record 12 of Set 4 | fort dodge
# Processing Record 13 of Set 4 | bogorodskoye
# Processing Record 14 of Set 4 | pecos
# Processing Record 15 of Set 4 | oga
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | raudeberg
# Processing Record 18 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | bima
# Processing Record 21 of Set 4 | ballia
# Processing Record 22 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 4 | sambava
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | tocopilla
# Processing Record 26 of Set 4 | cap malheureux
# Processing Record 27 of Set 4 | beringovskiy
# Processing Record 28 of Set 4 | waitati
# Processing Record 29 of Set 4 | tuatapere
# Processing Record 30 of Set 4 | deder
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | khatima
# Processing Record 34 of Set 4 | tautira
# Processing Record 35 of Set 4 | salinas
# Processing Record 36 of Set 4 | khandyga
# Processing Record 37 of Set 4 | show low
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | porto walter
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | wundanyi
# Processing Record 42 of Set 4 | mar del plata
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | cockburn town
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | abha
# Processing Record 47 of Set 4 | lazaro cardenas
# Processing Record 48 of Set 4 | qaanaaq
# Processing Record 49 of Set 4 | nishihara
# Processing Record 50 of Set 4 | monrovia
# Processing Record 1 of Set 5 | khartoum
# Processing Record 2 of Set 5 | mednogorsk
# Processing Record 3 of Set 5 | san matias
# Processing Record 4 of Set 5 | saint-francois
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | wittstock
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | arraial do cabo
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | lucapa
# Processing Record 11 of Set 5 | townsville
# Processing Record 12 of Set 5 | seoul
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | berlevag
# Processing Record 15 of Set 5 | kahta
# Processing Record 16 of Set 5 | jining
# Processing Record 17 of Set 5 | muros
# Processing Record 18 of Set 5 | san patricio
# Processing Record 19 of Set 5 | praia
# Processing Record 20 of Set 5 | parabel
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | nerchinskiy zavod
# Processing Record 23 of Set 5 | tarazona
# Processing Record 24 of Set 5 | sioux lookout
# Processing Record 25 of Set 5 | lachi
# Processing Record 26 of Set 5 | san andres
# Processing Record 27 of Set 5 | hofn
# Processing Record 28 of Set 5 | roald
# Processing Record 29 of Set 5 | henties bay
# Processing Record 30 of Set 5 | kawalu
# Processing Record 31 of Set 5 | biltine
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | la ronge
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 37 of Set 5 | biak
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | idritsa
# Processing Record 40 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 5 | hokitika
# Processing Record 42 of Set 5 | alyangula
# Processing Record 43 of Set 5 | paamiut
# Processing Record 44 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 5 | kaitangata
# Processing Record 46 of Set 5 | port-gentil
# Processing Record 47 of Set 5 | cidreira
# Processing Record 48 of Set 5 | vila velha
# Processing Record 49 of Set 5 | north bend
# Processing Record 50 of Set 5 | rundu
# Processing Record 1 of Set 6 | padang
# Processing Record 2 of Set 6 | mangalam
# Processing Record 3 of Set 6 | siocon
# Processing Record 4 of Set 6 | ramhormoz
# Processing Record 5 of Set 6 | okakarara
# Processing Record 6 of Set 6 | harlingen
# Processing Record 7 of Set 6 | whyalla
# Processing Record 8 of Set 6 | fortuna
# Processing Record 9 of Set 6 | cherskiy
# Processing Record 10 of Set 6 | mount isa
# Processing Record 11 of Set 6 | aldan
# Processing Record 12 of Set 6 | tartagal
# Processing Record 13 of Set 6 | hermosillo
# Processing Record 14 of Set 6 | ostrovnoy
# Processing Record 15 of Set 6 | natal
# Processing Record 16 of Set 6 | luwuk
# Processing Record 17 of Set 6 | dandong
# Processing Record 18 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 6 | gorom-gorom
# Processing Record 20 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 21 of Set 6 | kovur
# Processing Record 22 of Set 6 | foz
# Processing Record 23 of Set 6 | vestmannaeyjar
# Processing Record 24 of Set 6 | isangel
# Processing Record 25 of Set 6 | xining
# Processing Record 26 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 6 | namatanai
# Processing Record 28 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 6 | pimenta bueno
# Processing Record 30 of Set 6 | waingapu
# Processing Record 31 of Set 6 | belaya gora
# Processing Record 32 of Set 6 | beloha
# Processing Record 33 of Set 6 | nantucket
# Processing Record 34 of Set 6 | areka
# Processing Record 35 of Set 6 | kralendijk
# Processing Record 36 of Set 6 | yining
# Processing Record 37 of Set 6 | troitskoye
# Processing Record 38 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 6 | huarmey
# Processing Record 40 of Set 6 | dalton
# Processing Record 41 of Set 6 | riyadh
# Processing Record 42 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 6 | erzin
# Processing Record 44 of Set 6 | pemangkat
# Processing Record 45 of Set 6 | saint-pierre
# Processing Record 46 of Set 6 | antofagasta
# Processing Record 47 of Set 6 | shelburne
# Processing Record 48 of Set 6 | buraydah
# Processing Record 49 of Set 6 | arkadak
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 1 of Set 7 | pacasmayo
# Processing Record 2 of Set 7 | aksarka
# Processing Record 3 of Set 7 | ola
# Processing Record 4 of Set 7 | thurso
# Processing Record 5 of Set 7 | katsuura
# Processing Record 6 of Set 7 | itoman
# Processing Record 7 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | clyde river
# Processing Record 9 of Set 7 | porto belo
# Processing Record 10 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 7 | ancud
# Processing Record 12 of Set 7 | pucallpa
# Processing Record 13 of Set 7 | darhan
# Processing Record 14 of Set 7 | nome
# Processing Record 15 of Set 7 | asau
# Processing Record 16 of Set 7 | nyurba
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | sindor
# Processing Record 19 of Set 7 | taoudenni
# Processing Record 20 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 7 | mikkeli
# Processing Record 22 of Set 7 | zverinogolovskoye
# Processing Record 23 of Set 7 | faya
# Processing Record 24 of Set 7 | itarema
# Processing Record 25 of Set 7 | ternate
# Processing Record 26 of Set 7 | musoma
# Processing Record 27 of Set 7 | inirida
# Processing Record 28 of Set 7 | volchikha
# Processing Record 29 of Set 7 | liuhe
# Processing Record 30 of Set 7 | frunze
# Processing Record 31 of Set 7 | victoria
# Processing Record 32 of Set 7 | sotuta
# Processing Record 33 of Set 7 | neiafu
# Processing Record 34 of Set 7 | alofi
# Processing Record 35 of Set 7 | roros
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | makat
# Processing Record 39 of Set 7 | ponta delgada
# Processing Record 40 of Set 7 | yulara
# Processing Record 41 of Set 7 | zalantun
# Processing Record 42 of Set 7 | pabna
# Processing Record 43 of Set 7 | nioro
# Processing Record 44 of Set 7 | madang
# Processing Record 45 of Set 7 | kirakira
# Processing Record 46 of Set 7 | sikonge
# Processing Record 47 of Set 7 | esperance
# Processing Record 48 of Set 7 | kuah
# Processing Record 49 of Set 7 | cayenne
# Processing Record 50 of Set 7 | gamba
# Processing Record 1 of Set 8 | mtwara
# Processing Record 2 of Set 8 | havoysund
# Processing Record 3 of Set 8 | christchurch
# Processing Record 4 of Set 8 | lompoc
# Processing Record 5 of Set 8 | sur
# Processing Record 6 of Set 8 | dar es salaam
# Processing Record 7 of Set 8 | comodoro rivadavia
# Processing Record 8 of Set 8 | caruray
# Processing Record 9 of Set 8 | moree
# Processing Record 10 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 8 | atasu
# Processing Record 12 of Set 8 | broome
# Processing Record 13 of Set 8 | alexandria
# Processing Record 14 of Set 8 | manyana
# Processing Record 15 of Set 8 | honiara
# Processing Record 16 of Set 8 | compiegne
# Processing Record 17 of Set 8 | sinnamary
# Processing Record 18 of Set 8 | kabarnet
# Processing Record 19 of Set 8 | altay
# Processing Record 20 of Set 8 | encruzilhada do sul
# Processing Record 21 of Set 8 | klaksvik
# Processing Record 22 of Set 8 | toora-khem
# Processing Record 23 of Set 8 | mahon
# Processing Record 24 of Set 8 | sopotnica
# Processing Record 25 of Set 8 | dudinka
# Processing Record 26 of Set 8 | san bartolo
# Processing Record 27 of Set 8 | auki
# Processing Record 28 of Set 8 | lazo
# Processing Record 29 of Set 8 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 30 of Set 8 | gwembe
# Processing Record 31 of Set 8 | okhotsk
# Processing Record 32 of Set 8 | douglas
# Processing Record 33 of Set 8 | shingu
# Processing Record 34 of Set 8 | olafsvik
# Processing Record 35 of Set 8 | byron bay
# Processing Record 36 of Set 8 | patea
# Processing Record 37 of Set 8 | shurugwi
# Processing Record 38 of Set 8 | tura
# Processing Record 39 of Set 8 | polyarnyy
# Processing Record 40 of Set 8 | saldanha
# Processing Record 41 of Set 8 | mombasa
# Processing Record 42 of Set 8 | deputatskiy
# Processing Record 43 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 44 of Set 8 | conde
# Processing Record 45 of Set 8 | margate
# Processing Record 46 of Set 8 | eregli
# Processing Record 47 of Set 8 | oeiras do para
# Processing Record 48 of Set 8 | moron
# Processing Record 49 of Set 8 | port blair
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | boysun
# Processing Record 2 of Set 9 | ilulissat
# Processing Record 3 of Set 9 | nabire
# Processing Record 4 of Set 9 | mangaratiba
# Processing Record 5 of Set 9 | qujing
# Processing Record 6 of Set 9 | vattalkundu
# Processing Record 7 of Set 9 | aguas verdes
# Processing Record 8 of Set 9 | santa fe
# Processing Record 9 of Set 9 | baoding
# Processing Record 10 of Set 9 | chipinge
# Processing Record 11 of Set 9 | grand gaube
# Processing Record 12 of Set 9 | severo-kurilsk
# Processing Record 13 of Set 9 | bathsheba
# Processing Record 14 of Set 9 | aksu
# Processing Record 15 of Set 9 | srednekolymsk
# Processing Record 16 of Set 9 | pisco
# Processing Record 17 of Set 9 | garissa
# Processing Record 18 of Set 9 | pomabamba
# Processing Record 19 of Set 9 | bodden town
# Processing Record 20 of Set 9 | novyy urengoy
# Processing Record 21 of Set 9 | half moon bay
# Processing Record 22 of Set 9 | ribeira grande
# Processing Record 23 of Set 9 | washougal
# Processing Record 24 of Set 9 | mayo
# Processing Record 25 of Set 9 | saurimo
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | tomatlan
# Processing Record 28 of Set 9 | vitoria da conquista
# Processing Record 29 of Set 9 | vanavara
# Processing Record 30 of Set 9 | zabid
# Processing Record 31 of Set 9 | umm lajj
# Processing Record 32 of Set 9 | rocha
# Processing Record 33 of Set 9 | dunmore town
# Processing Record 34 of Set 9 | meadow lake
# Processing Record 35 of Set 9 | tessalit
# Processing Record 36 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 9 | chase
# Processing Record 38 of Set 9 | denizli
# Processing Record 39 of Set 9 | yumen
# Processing Record 40 of Set 9 | punta alta
# Processing Record 41 of Set 9 | sheregesh
# Processing Record 42 of Set 9 | dombas
# Processing Record 43 of Set 9 | cortez
# Processing Record 44 of Set 9 | murgab
# Processing Record 45 of Set 9 | talnakh
# Processing Record 46 of Set 9 | pacific grove
# Processing Record 47 of Set 9 | meybod
# Processing Record 48 of Set 9 | arrecife
# Processing Record 49 of Set 9 | workington
# Processing Record 50 of Set 9 | waddan
# Processing Record 1 of Set 10 | nueva loja
# Processing Record 2 of Set 10 | eyl
# Processing Record 3 of Set 10 | vilhena
# Processing Record 4 of Set 10 | dharchula
# Processing Record 5 of Set 10 | forrest city
# Processing Record 6 of Set 10 | lamu
# Processing Record 7 of Set 10 | bukama
# Processing Record 8 of Set 10 | richards bay
# Processing Record 9 of Set 10 | pochutla
# Processing Record 10 of Set 10 | dunedin
# Processing Record 11 of Set 10 | bury saint edmunds
# City not found. Skipping...
# Processing Record 12 of Set 10 | feijo
# Processing Record 13 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 10 | alihe
# Processing Record 15 of Set 10 | san isidro
# Processing Record 16 of Set 10 | burnie
# Processing Record 17 of Set 10 | sao miguel
# Processing Record 18 of Set 10 | pachino
# Processing Record 19 of Set 10 | taltal
# Processing Record 20 of Set 10 | constitucion
# Processing Record 21 of Set 10 | kavieng
# Processing Record 22 of Set 10 | solvychegodsk
# Processing Record 23 of Set 10 | bolonchen
# City not found. Skipping...
# Processing Record 24 of Set 10 | lumeje
# Processing Record 25 of Set 10 | fairbanks
# Processing Record 26 of Set 10 | suntar
# Processing Record 27 of Set 10 | hamilton
# Processing Record 28 of Set 10 | stornoway
# Processing Record 29 of Set 10 | dukat
# Processing Record 30 of Set 10 | bria
# Processing Record 31 of Set 10 | hobyo
# Processing Record 32 of Set 10 | morden
# Processing Record 33 of Set 10 | krasnyy yar
# Processing Record 34 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 10 | poum
# Processing Record 37 of Set 10 | kincardine
# Processing Record 38 of Set 10 | atar
# Processing Record 39 of Set 10 | fayetteville
# Processing Record 40 of Set 10 | port hawkesbury
# Processing Record 41 of Set 10 | meulaboh
# Processing Record 42 of Set 10 | wenling
# Processing Record 43 of Set 10 | kununurra
# Processing Record 44 of Set 10 | gryazi
# Processing Record 45 of Set 10 | pimentel
# Processing Record 46 of Set 10 | lagoa
# Processing Record 47 of Set 10 | walvis bay
# Processing Record 48 of Set 10 | fulton
# Processing Record 49 of Set 10 | forbes
# Processing Record 50 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 11 | turukhansk
# Processing Record 2 of Set 11 | disraeli
# Processing Record 3 of Set 11 | seymchan
# Processing Record 4 of Set 11 | pantai remis
# Processing Record 5 of Set 11 | the valley
# Processing Record 6 of Set 11 | rawson
# Processing Record 7 of Set 11 | novomykolayivka
# Processing Record 8 of Set 11 | maniitsoq
# Processing Record 9 of Set 11 | mareeba
# Processing Record 10 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 11 | yaan
# Processing Record 12 of Set 11 | grimsby
# Processing Record 13 of Set 11 | saint george
# Processing Record 14 of Set 11 | valley city
# Processing Record 15 of Set 11 | rabo de peixe
# Processing Record 16 of Set 11 | las vegas
# Processing Record 17 of Set 11 | olinda
# Processing Record 18 of Set 11 | carutapera
# Processing Record 19 of Set 11 | brigantine
# Processing Record 20 of Set 11 | buchanan
# Processing Record 21 of Set 11 | mangan
# Processing Record 22 of Set 11 | ust-tsilma
# Processing Record 23 of Set 11 | quchan
# Processing Record 24 of Set 11 | hay river
# Processing Record 25 of Set 11 | port augusta
# Processing Record 26 of Set 11 | los alamos
# Processing Record 27 of Set 11 | doha
# Processing Record 28 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 29 of Set 11 | monroe
# Processing Record 30 of Set 11 | edson
# Processing Record 31 of Set 11 | talaya
# Processing Record 32 of Set 11 | niort
# Processing Record 33 of Set 11 | ha giang
# Processing Record 34 of Set 11 | bombay
# Processing Record 35 of Set 11 | sao luiz gonzaga
# Processing Record 36 of Set 11 | plouzane
# Processing Record 37 of Set 11 | egvekinot
# Processing Record 38 of Set 11 | msanga
# Processing Record 39 of Set 11 | belyy yar
# Processing Record 40 of Set 11 | nemuro
# Processing Record 41 of Set 11 | sibu
# Processing Record 42 of Set 11 | daru
# Processing Record 43 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 11 | togur
# Processing Record 45 of Set 11 | makakilo city
# Processing Record 46 of Set 11 | omboue
# Processing Record 47 of Set 11 | college
# Processing Record 48 of Set 11 | vardo
# Processing Record 49 of Set 11 | lasa
# Processing Record 50 of Set 11 | rio grande
# Processing Record 1 of Set 12 | pilar
# Processing Record 2 of Set 12 | manzhouli
# Processing Record 3 of Set 12 | santa maria
# Processing Record 4 of Set 12 | pathein
# Processing Record 5 of Set 12 | bangui
# Processing Record 6 of Set 12 | batemans bay
# Processing Record 7 of Set 12 | ulladulla
# Processing Record 8 of Set 12 | dhidhdhoo
# Processing Record 9 of Set 12 | den helder
# Processing Record 10 of Set 12 | muisne
# Processing Record 11 of Set 12 | suamico
# Processing Record 12 of Set 12 | shaturtorf
# Processing Record 13 of Set 12 | grand baie
# Processing Record 14 of Set 12 | hit
# Processing Record 15 of Set 12 | wewak
# Processing Record 16 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 17 of Set 12 | kalangala
# Processing Record 18 of Set 12 | rajshahi
# Processing Record 19 of Set 12 | maceio
# Processing Record 20 of Set 12 | cache creek
# Processing Record 21 of Set 12 | tornio
# Processing Record 22 of Set 12 | kuryk
# Processing Record 23 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 12 | eureka
# Processing Record 25 of Set 12 | svetlogorsk
# Processing Record 26 of Set 12 | te anau
# Processing Record 27 of Set 12 | traverse city
# Processing Record 28 of Set 12 | mecca
# Processing Record 29 of Set 12 | laguna
# Processing Record 30 of Set 12 | lang son
# Processing Record 31 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 12 | tirano
# Processing Record 33 of Set 12 | buturlinovka
# Processing Record 34 of Set 12 | mpongwe
# Processing Record 35 of Set 12 | gornouralskiy
# City not found. Skipping...
# Processing Record 36 of Set 12 | shubarshi
# Processing Record 37 of Set 12 | mackay
# Processing Record 38 of Set 12 | tamandare
# Processing Record 39 of Set 12 | bac lieu
# Processing Record 40 of Set 12 | koudougou
# Processing Record 41 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 42 of Set 12 | chumikan
# Processing Record 43 of Set 12 | ranong
# Processing Record 44 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 12 | bereda
# Processing Record 46 of Set 12 | krasnoselkup
# Processing Record 47 of Set 12 | kamenka
# Processing Record 48 of Set 12 | voskresenskoye
# Processing Record 49 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 12 | astorga
# Processing Record 1 of Set 13 | mogadouro
# Processing Record 2 of Set 13 | mutsu
# Processing Record 3 of Set 13 | batsfjord
# Processing Record 4 of Set 13 | bahawalnagar
# Processing Record 5 of Set 13 | birjand
# Processing Record 6 of Set 13 | savannah bight
# Processing Record 7 of Set 13 | cody
# Processing Record 8 of Set 13 | narsaq
# Processing Record 9 of Set 13 | osypenko
# Processing Record 10 of Set 13 | tambovka
# Processing Record 11 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 12 of Set 13 | suzun
# Processing Record 13 of Set 13 | zhezkazgan
# Processing Record 14 of Set 13 | port moresby
# Processing Record 15 of Set 13 | owensboro
# Processing Record 16 of Set 13 | schongau
# Processing Record 17 of Set 13 | nikki
# Processing Record 18 of Set 13 | shirdi
# Processing Record 19 of Set 13 | pakala
# Processing Record 20 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 13 | marienburg
# Processing Record 22 of Set 13 | hervey bay
# Processing Record 23 of Set 13 | pedernales
# Processing Record 24 of Set 13 | rena
# Processing Record 25 of Set 13 | lewistown
# Processing Record 26 of Set 13 | kislang
# Processing Record 27 of Set 13 | dhar
# Processing Record 28 of Set 13 | hovin
# Processing Record 29 of Set 13 | mana
# Processing Record 30 of Set 13 | cachoeira do sul
# Processing Record 31 of Set 13 | alfonsine
# Processing Record 32 of Set 13 | chiredzi
# Processing Record 33 of Set 13 | solnechnyy
# Processing Record 34 of Set 13 | galveston
# Processing Record 35 of Set 13 | goderich
# Processing Record 36 of Set 13 | lismore
# Processing Record 37 of Set 13 | champerico
# Processing Record 38 of Set 13 | raahe
# Processing Record 39 of Set 13 | perth
# Processing Record 40 of Set 13 | chunoyar
# Processing Record 41 of Set 13 | makung
# City not found. Skipping...
# Processing Record 42 of Set 13 | bezhanitsy
# Processing Record 43 of Set 13 | treinta y tres
# Processing Record 44 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 13 | aluksne
# Processing Record 46 of Set 13 | waipawa
# Processing Record 47 of Set 13 | shenjiamen
# Processing Record 48 of Set 13 | cordoba
# Processing Record 49 of Set 13 | mineiros
# Processing Record 50 of Set 13 | awbari
# Processing Record 1 of Set 14 | rio tuba
# Processing Record 2 of Set 14 | shaoguan
# Processing Record 3 of Set 14 | lodja
# Processing Record 4 of Set 14 | baghdad
# Processing Record 5 of Set 14 | qaqortoq
# Processing Record 6 of Set 14 | billings
# Processing Record 7 of Set 14 | ampanihy
# Processing Record 8 of Set 14 | geraldton
# Processing Record 9 of Set 14 | seaforth
# Processing Record 10 of Set 14 | bayji
# Processing Record 11 of Set 14 | rapid valley
# Processing Record 12 of Set 14 | farsund
# Processing Record 13 of Set 14 | fecamp
# Processing Record 14 of Set 14 | hibbing
# Processing Record 15 of Set 14 | kattivakkam
# Processing Record 16 of Set 14 | huaihua
# Processing Record 17 of Set 14 | orotukan
# Processing Record 18 of Set 14 | dingle
# Processing Record 19 of Set 14 | san quintin
# Processing Record 20 of Set 14 | soe
# Processing Record 21 of Set 14 | sretensk
# Processing Record 22 of Set 14 | chuguyevka
# Processing Record 23 of Set 14 | sarkand
# Processing Record 24 of Set 14 | coahuayana
# Processing Record 25 of Set 14 | kaeo
# Processing Record 26 of Set 14 | west odessa
# Processing Record 27 of Set 14 | gardner
# Processing Record 28 of Set 14 | oreanda
# City not found. Skipping...
# Processing Record 29 of Set 14 | jurm
# Processing Record 30 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 31 of Set 14 | rio gallegos
# Processing Record 32 of Set 14 | yingzhong
# City not found. Skipping...
# Processing Record 33 of Set 14 | caravelas
# Processing Record 34 of Set 14 | kill
# Processing Record 35 of Set 14 | moroni
# Processing Record 36 of Set 14 | noyabrsk
# Processing Record 37 of Set 14 | nautanwa
# Processing Record 38 of Set 14 | agbor
# Processing Record 39 of Set 14 | westport
# Processing Record 40 of Set 14 | rongcheng
# Processing Record 41 of Set 14 | la plata
# Processing Record 42 of Set 14 | lavrentiya
# Processing Record 43 of Set 14 | tarauaca
# Processing Record 44 of Set 14 | rorvik
# Processing Record 45 of Set 14 | port hedland
# Processing Record 46 of Set 14 | divnomorskoye
# Processing Record 47 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 14 | lewiston
# Processing Record 49 of Set 14 | turayf
# Processing Record 50 of Set 14 | sangar
# Processing Record 1 of Set 15 | voh
# Processing Record 2 of Set 15 | namibe
# Processing Record 3 of Set 15 | kangaatsiaq
# Processing Record 4 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 5 of Set 15 | cacu
# Processing Record 6 of Set 15 | west wendover
# Processing Record 7 of Set 15 | oktyabrskiy
# Processing Record 8 of Set 15 | mirador
# Processing Record 9 of Set 15 | kirensk
# Processing Record 10 of Set 15 | peniche
# Processing Record 11 of Set 15 | serenje
# Processing Record 12 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 15 | iquique
# Processing Record 14 of Set 15 | sukhobezvodnoye
# Processing Record 15 of Set 15 | matara
# Processing Record 16 of Set 15 | penha
# Processing Record 17 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 15 | sovetskiy
# Processing Record 20 of Set 15 | najran
# Processing Record 21 of Set 15 | urucui
# Processing Record 22 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 15 | stepnoye
# Processing Record 24 of Set 15 | mont-dore
# Processing Record 25 of Set 15 | ayaviri
# Processing Record 26 of Set 15 | noumea
# Processing Record 27 of Set 15 | zarubino
# Processing Record 28 of Set 15 | yeppoon
# Processing Record 29 of Set 15 | gimli
# Processing Record 30 of Set 15 | jiangyou
# Processing Record 31 of Set 15 | tchollire
# Processing Record 32 of Set 15 | tondano
# Processing Record 33 of Set 15 | korla
# Processing Record 34 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 15 | nicoya
# Processing Record 36 of Set 15 | rio bueno
# Processing Record 37 of Set 15 | narayangarh
# Processing Record 38 of Set 15 | khasan
# Processing Record 39 of Set 15 | londoko
# Processing Record 40 of Set 15 | millau
# Processing Record 41 of Set 15 | port lincoln
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0   New Norfolk -42.7826  147.0587          few clouds     60.30        89
# 1     Tazovskiy  67.4667   78.7000          few clouds    -21.41        99
# 2   Yerbogachen  61.2767  108.0108     overcast clouds      5.74        97
# 3      La Rioja  42.2500   -2.5000           clear sky     47.05        88
# 4      Khatanga  71.9667  102.5000       broken clouds    -38.02       100
# 5      Hermanus -34.4187   19.2345       broken clouds     69.91        73
# 6       Salalah  17.0151   54.0924           clear sky     80.69        19
# 7  Komsomolskiy  40.4272   71.7189                mist     40.42        70
# 8        Barrow  71.2906 -156.7887                haze    -16.58        69
# 9         Airai  -8.9266  125.4092     overcast clouds     62.13        89
#
#    Cloudiness  Wind Speed Country
# 0          11        3.42      AU
# 1          19        7.05      RU
# 2         100        2.28      RU
# 3           7        4.56      ES
# 4          76        2.75      RU
# 5          74        9.73      ZA
# 6           0        8.05      OM
# 7          61        2.30      UZ
# 8          20        9.22      US
# 9         100        1.81      TL

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   New Norfolk      AU -42.7826  147.0587     60.30        89          11
# 1     Tazovskiy      RU  67.4667   78.7000    -21.41        99          19
# 2   Yerbogachen      RU  61.2767  108.0108      5.74        97         100
# 3      La Rioja      ES  42.2500   -2.5000     47.05        88           7
# 4      Khatanga      RU  71.9667  102.5000    -38.02       100          76
# 5      Hermanus      ZA -34.4187   19.2345     69.91        73          74
# 6       Salalah      OM  17.0151   54.0924     80.69        19           0
# 7  Komsomolskiy      UZ  40.4272   71.7189     40.42        70          61
# 8        Barrow      US  71.2906 -156.7887    -16.58        69          20
# 9         Airai      TL  -8.9266  125.4092     62.13        89         100
#
#    Wind Speed Current Description
# 0        3.42          few clouds
# 1        7.05          few clouds
# 2        2.28     overcast clouds
# 3        4.56           clear sky
# 4        2.75       broken clouds
# 5        9.73       broken clouds
# 6        8.05           clear sky
# 7        2.30                mist
# 8        9.22                haze
# 9        1.81     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
